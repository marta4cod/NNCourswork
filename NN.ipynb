# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/Github
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/Github

# %%
# !git clone https://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@github.com/marta4cod/NNCourswork
# Out:
# fatal: destination path 'NNCourswork' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/Github/NNCourswork
# Out:
# /content/drive/MyDrive/Github/NNCourswork

# %%
# %ls -a
# Out:
# .git/  README.md

# %%
# !git status
# !git add student_lifestyle_dataset.csv
# !git commit -m "commit"
# !git pull
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	NNCoursework.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# fatal: pathspec 'NNCourswork.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	NNCoursework.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# Already up to date.
# Everything up-to-date

# %% [markdown]
# Upload the data

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Github/NNCourswork/student_lifestyle_dataset.csv')

# %%
# !git status
# !git add '/content/drive/MyDrive/Colab Notebooks/NNCoursework.ipynb'
# !git commit -m "push the file"
# !git pull
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: /content/drive/MyDrive/Colab Notebooks/NNCoursework.ipynb: '/content/drive/MyDrive/Colab Notebooks/NNCoursework.ipynb' is outside repository at '/content/drive/MyDrive/Github/NNCourswork'
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Already up to date.
# Everything up-to-date
